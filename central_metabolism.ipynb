# %%
import cobra
from cobra import Reaction, Metabolite, Model
from cobra.util.solver import linear_reaction_coefficients

testing_model = Model("Central_metabolism")

#TO DO Metabolites

amp_c=Metabolite('amp_c',
                   name='AMP',
                   formula='C10H12N5O7P',
                   compartment='c',
                   charge= -2
                   )

#ATP
atp_c = Metabolite('atp_c',
                   name='ATP',
                   formula='C10H12N5O13P3',
                   compartment='c',
                   charge= -4
                   )
#ADP
adp_c = Metabolite('adp_c',
                   name='ADP',
                   formula='C10H12N5O10P2',
                   compartment='c',
                   charge= -3
                   )
#D-Glucose
glc__D_c = Metabolite('glc__D_c',
                   name='D-Glucose',
                   formula='C6H12O6',
                   compartment='c',
                   charge= 0
                   )
#D-Glucose 6-phosphate
g6p_c = Metabolite('g6p_c',
                   name='D-Glucose 6-phosphate',
                   formula='C6H11O9P',
                   compartment='c',
                   charge= -2
                   )
#H+
h_c = Metabolite('h_c',
                   name='H+',
                   formula='H',
                   compartment='c',
                   charge= +1 #имеет 2 заряда (0,+1) смотрим по ЗСЗ в уравнении -> иончик.
                   )
#H+
h_e = Metabolite('h_e',
                   name='H+',
                   formula='H',
                   compartment='e',
                   charge= +1 #имеет 2 заряда (0,+1) смотрим по ЗСЗ в уравнении -> иончик.
                   )
#D-Glucose external
glc_D_e = Metabolite('glc_D_e',
                   name='D-Glucose',
                   formula='C6H12O6',
                   compartment='e',
                   )
#D-Fructose_6-phosphate
f6p_c = Metabolite('f6p_c',
                   name='D-Fructose_6-phosphate',
                   formula='C6H11O9P',
                   compartment='c',
                   charge= -2
                   )
#D-Fructose 1,6-bisphosphate
fdp_c = Metabolite('fdp_c',
                   name='D-Fructose 1,6-bisphosphate',
                   formula='C6H10O12P2',
                   compartment='c',
                   charge= -4
                   )
#glycerone phosphate
dhap_c = Metabolite('dhap',
                   name='Glycerone-phosphate',
                   formula='C3H5O6P',
                   compartment='c',
                   charge= -2
                   )

#D-glyceraldehyde 3-phosphate
g3p_c = Metabolite('g3p_c',
                   name='Glyceraldehyde 3-phosphate',
                   formula='C3H5O6P',
                   compartment='c',
                   charge= -2
                   )

#3-phospho-D-glycerate
pg3_c = Metabolite('3pg_c',
                   name='3-Phospho-D-glycerate',
                   formula='C3H4O7P',
                   compartment='c',
                   charge= -3
                   )

#Phosphate
pi_c = Metabolite('pi_c',
                   name='Phosphate',
                   formula='HPO4',
                   compartment='c',
                   charge= -2
                   )

#3-phospho-D-glyceroyl phosphate
dpg13_c = Metabolite('13dpg_c',
                   name='3-phospho-D-glyceroyl phosphate',
                   formula='C3H4O10P2',
                   compartment='c',
                   charge= -4
                   )

#2-phospho-D-glycerate
pg2_c = Metabolite('2pg_c',
                   name='2-phospho-D-glycerate',
                   formula='C3H4O7P',
                   compartment='c',
                   charge= -3
                   )

#phosphoenolpyruvate
pep_c = Metabolite('pep_c',
                   name='Phosphoenolpyruvate',
                   formula='C3H2O6P',
                   compartment='c',
                   charge= -3
                   )

#H2O
h2o_c = Metabolite('h2o_c',
                   name='H2O',
                   formula='H2O',
                   compartment='c',
                   charge= 0
                   )

#pyruvate
pyr_c = Metabolite('pyr_c',
                   name='Pyruvate',
                   formula='C3H3O3',
                   compartment='c',
                   charge= -1
                   )

#oxaloacetate
oaa_c = Metabolite('oaa_c',
                   name='Oxaloacetate',
                   formula='C4H2O5',
                   compartment='c',
                   charge= -2
                   )

#CO2
co2_c = Metabolite('co2_c',
                   name='CO2',
                   formula='CO2',
                   compartment='c',
                   charge= 0
                   )

#nadph_c
nadh_c = Metabolite('nadh_c',
                   name='Nicotinamide adenine dinucleotide - reduced',
                   formula='C21H27N7O14P2',
                   compartment='c',
                   charge= -2
                   )

#nadph_c
nadph_c = Metabolite('nadph_c',
                   name='Nicotinamide adenine dinucleotide phosphate - reduced',
                   formula='C21H26N7O17P3',
                   compartment='c',
                   charge= -4
                   )

#nad_c
nad_c = Metabolite('nad_c',
                   name='Nicotinamide adenine dinucleotide',
                   formula='C21H26N7O14P2',
                   compartment='c',
                   charge= -1
                   )

#COA
coa_c = Metabolite('coa_c',
                   name='Coenzyme A',
                   formula='C21H32N7O16P3S',
                   compartment='c',
                   charge= -4
                   )

#Diphosphate
ppi_c = Metabolite('ppi_c',
                   name='Diphosphate',
                   formula='H1O7P2',
                   compartment='c',
                   charge= -3
                   )

#CAcetyl-CoA
accoa_c = Metabolite('accoa_c',
                   name='Acetyl-CoA',
                   formula='C23H34N7O17P3S',
                   compartment='c',
                   charge= -4
                   )

#Acetate
ac_c = Metabolite('ac_c',
                   name='Acetate',
                   formula='C2H3O2',
                   compartment='c',
                   charge= -1
                   )

#Acetaldehyde
acald_c = Metabolite('acald_c',
                   name='Acetaldehyde',
                   formula='C2H4O',
                   compartment='c',
                   charge= 0
                   )

#Nicotinamide adenine dinucleotide phosphate
nadp_c = Metabolite('nadp_c',
                   name='Nicotinamide adenine dinucleotide phosphate',
                   formula='C21H25N7O17P3',
                   compartment='c',
                   charge= -3
                   )

#Ethanol
etoh_c = Metabolite('etoh_c',
                   name='Ethanol',
                   formula='C2H6O',
                   compartment='c',
                   charge= 0
                   )
#Ethanol
etoh_e = Metabolite('etoh_e',
                   name='Ethanol',
                   formula='C2H6O',
                   compartment='e',
                   charge= 0
                   )
#Bicarbonate
hco3_c = Metabolite('hco3_c',
                   name='Bicarbonate',
                   formula='HCO3',
                   compartment='c',
                   charge= -1
                   )

#cit
cit_c = Metabolite('cit_c',
                   name='Citrate',
                   formula='C6H5O7',
                   compartment='c',
                   charge= -3
                   )

#L-Malate
mal__L_c = Metabolite('mal__L_c',
                   name='L-Malate',
                   formula='C4H4O5',
                   compartment='c',
                   charge= -2
                   )


#Isocitrate
icit_c = Metabolite('icit_c',
                   name='Isocitrate',
                   formula='C6H5O7',
                   compartment='c',
                   charge= -3
                   )

#2-Oxoglutarate
akg_c = Metabolite('akg_c',
                   name='2-Oxoglutarate',
                   formula='C5H4O5',
                   compartment='c',
                   charge= -2
                   )

#Lipoamide
lpam_c = Metabolite('lpam_c',
                   name='Lipoamide',
                   formula='C8H15NOS2',
                   compartment='c',
                   charge= 0
                   )

#S Succinyldihydrolipoamide
sdhlam_c = Metabolite('sdhlam_c',
                   name='S Succinyldihydrolipoamide',
                   formula='C12H20NO4S2',
                   compartment='c',
                   charge= -1
                   )

#Dihydrolipoamide
dhlam_c = Metabolite('dhlam_c',
                   name='Dihydrolipoamide',
                   formula='C8H17NOS2',
                   compartment='c',
                   charge= 0
                   )

#Succinyl-CoA
succoa_c = Metabolite('succoa_c',
                   name='Succinyl-CoA',
                   formula='C25H35N7O19P3S',
                   compartment='c',
                   charge= -5
                   )

#Succinate
succ_c = Metabolite('succ_c',
                   name='Succinate',
                   formula='C4H4O4',
                   compartment='c',
                   charge= -2
                   )

#Fumarate
fum_c = Metabolite('fum_c',
                   name='Fumarate',
                   formula='C4H2O4',
                   compartment='c',
                   charge= -2
                   )


#Flavin adenine dinucleotide reduced
fadh2_c = Metabolite('fadh2_c',
                   name='Flavin adenine dinucleotide reduced',
                   formula='C27H33N9O15P2',
                   compartment='c',
                   charge= -2
                   )

#Flavin adenine dinucleotide oxidized
fad_c = Metabolite('fad_c',
                   name='Flavin adenine dinucleotide oxidized',
                   formula='C27H31N9O15P2',
                   compartment='c',
                   charge= -2
                   )

# %%
# TO DO reactions

# atp_c + glc__D_c ⇌ adp_c + g6p_c + h_c
hex1 = Reaction('HEX1')
hex1.name = 'ATP:D-glucose 6-phosphotransferase'
hex1.subsystem = 'Glycolysis'
hex1.lower_bound = -1000
hex1.upper_bound = 1000
hex1.annotation = {'bigg.reaction': 'HEX1', 'seed.reaction': 'rxn00216'}
hex1.gene_reaction_rule = 'b2388' #KEGG левый верхний угол (розовый)
hex1.add_metabolites({atp_c: -1, glc__D_c: -1, g6p_c: 1, adp_c: 1, h_c: 1})

# d-glc => glc6f transport
glc_transport = Reaction('GLCt1')
glc_transport.name = 'Glucose transport uniport'
glc_transport.subsystem = 'Glycolysis'
glc_transport.lower_bound = -1000
glc_transport.upper_bound = 1000
glc_transport.annotation = {'bigg.reaction': 'GLCt1', 'seed.reaction': ' rxn08617'}
glc_transport.add_metabolites({glc_D_e:-1, glc__D_c:1})


# g6p_c ⇌ f6p_c
PGI = Reaction('PGI')
PGI.name = 'Glucose-6-phosphate_isomerase'
PGI.subsystem = 'Glycolysis'
PGI.lower_bound = -1000
PGI.upper_bound = 1000
PGI.gene_reaction_rule = 'BSU31350' #KEGG левый верхний угол
PGI.add_metabolites({ g6p_c: -1, f6p_c: 1})

# ATP + beta-D-Fructose 6-phosphate => ADP + beta-D-Fructose 1,6-bisphosphate
CDS = Reaction('CDS')
CDS.name = 'ATP:beta-D-fructose-6-phosphate 1-phosphotransferase'
CDS.subsystem = 'Glycolysis'
CDS.lower_bound = -1000
CDS.upper_bound = 1000
CDS.gene_reaction_rule = 'BSU29190' #KEGG левый верхний угол
CDS.add_metabolites({atp_c: -1, f6p_c: -1, fdp_c: 1, adp_c: 1, h_c:1})

# D-fructose-1,6-bisphosphate <=> Glycerone-phosphate + Glyceraldehyde3-phosphate
FBA = Reaction('FBA')
FBA.name = 'Fructose-bisphosphate aldolase'
FBA.subsystem = 'Glycolysis'
FBA.lower_bound = -1000
FBA.upper_bound = 1000
FBA.gene_reaction_rule = 'BSU37120' #KEGG левый верхний угол
FBA.add_metabolites({fdp_c : -1, dhap_c : 1, g3p_c: 1})


TPI = Reaction('TPI')
TPI.name = 'Triose-phosphate isomerase'
TPI.subsystem = 'Glycolysis'
TPI.lower_bound = -1000
TPI.upper_bound = 1000
TPI.gene_reaction_rule = 'BSU33920' #KEGG левый верхний угол
TPI.add_metabolites({dhap_c : 1, g3p_c: -1})

#D-glyceraldehyde 3-phosphate + phosphate + NAD+ = 3-phospho-D-glyceroyl phosphate + NADH + H+
GAPD = Reaction('GAPD')
GAPD.name = 'Glyceraldehyde-3-phosphate dehydrogenase'
GAPD.subsystem = 'Glycolysis'
GAPD.lower_bound = -1000
GAPD.upper_bound = 1000
GAPD.gene_reaction_rule = 'BSU33940' #KEGG левый верхний угол
GAPD.add_metabolites({g3p_c: 1, nad_c: 1, pi_c: 1, dpg13_c: -1, nadh_c: -1, h_c: -1})

#D-glyceraldehyde 3-phosphate + phosphate + NAD(P)+ = 3-phospho-D-glyceroyl phosphate + NAD(P)H + H+
GAPDi_nadp = Reaction('GAPDi_nadp')
GAPDi_nadp.name = 'Glyceraldehyde-3-phosphate dehydrogenase (NAD(P)+)'
GAPDi_nadp.subsystem = 'Glycolysis'
GAPDi_nadp.lower_bound = -1000
GAPDi_nadp.upper_bound = 1000
GAPDi_nadp.gene_reaction_rule = 'BSU29020' #KEGG левый верхний угол
GAPDi_nadp.add_metabolites({dpg13_c: 1, h_c : 1, nadph_c : 1, g3p_c: -1,nadp_c: -1, pi_c: -1})

#3pg_c + atp_c ⇌ 13dpg_c + adp_c
PGK = Reaction('PGK')
PGK.name = 'Phosphoglycerate kinase'
PGK.subsystem = 'Glycolysis'
PGK.lower_bound = -1000
PGK.upper_bound = 1000
PGK.gene_reaction_rule = 'BSU33930' #KEGG левый верхний угол
PGK.add_metabolites({pg3_c: -1, atp_c: -1, dpg13_c: 1, adp_c: 1})

#2-Phospho-D-glycerate <=> 3-Phosphoglycerate
PGM = Reaction('PGM')
PGM.name = 'Phosphoglycerate mutase'
PGM.subsystem = 'Glycolysis'
PGM.lower_bound = -1000
PGM.upper_bound = 1000
PGM.gene_reaction_rule = 'BSU33910' #KEGG левый верхний угол
PGM.add_metabolites({pg3_c: -1, pg2_c: 1})

#2pg_c ⇌ h2o_c + pep_c 
ENO = Reaction('ENO')
ENO.name = 'Enolase'
ENO.subsystem = 'Glycolysis'
ENO.lower_bound = 0
ENO.upper_bound = 1000
ENO.gene_reaction_rule = 'BSU33900' #KEGG левый верхний угол
ENO.add_metabolites({pg2_c: -1, h2o_c: 1, pep_c: 1})

#adp_c + h_c + pep_c ⇌ atp_c + pyr_c
PYK = Reaction('PYK')
PYK.name = 'Pyruvate kinase'
PYK.subsystem = 'Glycolysis'
PYK.lower_bound = -1000
PYK.upper_bound = 1000
PYK.gene_reaction_rule = 'BSU29180' #KEGG левый верхний угол
PYK.add_metabolites({adp_c: -1, h_c: -1,  pep_c: -1, atp_c: 1, pyr_c: 1})

#atp_c + oaa_c ⇌ adp_c + co2_c + pep_c
PPCK = Reaction('PPCK')
PPCK.name = 'Phosphoenolpyruvate carboxykinase'
PPCK.subsystem = 'Glycolysis'
PPCK.lower_bound = -1000
PPCK.upper_bound = 1000
PPCK.gene_reaction_rule = 'BSU30560' #KEGG левый верхний угол
PPCK.add_metabolites({adp_c: -1, co2_c: -1, oaa_c: 1, atp_c: 1, pep_c: -1})

#atp_c + h2o_c + pyr_c ⇌ amp_c + 2.0 h_c + pep_c + pi_c
PPS = Reaction('PPS')
PPS.name = 'Phosphoenolpyruvate synthase'
PPS.subsystem = 'Glycolysis'
PPS.lower_bound = -1000
PPS.upper_bound = 1000
PPS.gene_reaction_rule = 'BSU35190' #KEGG левый верхний угол
PPS.add_metabolites({pyr_c: -1, h2o_c: -1, atp_c: -1, amp_c: 1, h_c: 2, pep_c: 1, pi_c: 1})


#ac_c + atp_c + coa_c ⇌ accoa_c + amp_c + ppi_c
ACS = Reaction('ACS')
ACS.name = 'Acetyl-CoA synthetase'
ACS.subsystem = 'Glycolysis'
ACS.lower_bound = -1000
ACS.upper_bound = 1000
ACS.gene_reaction_rule = 'BSU29560' #KEGG левый верхний угол
ACS.add_metabolites({accoa_c: -1, amp_c: -1, ppi_c: -1, ac_c: 1, atp_c: 1, coa_c: 1})



#acald_c + h2o_c + nad_c ⇌ ac_c + 2.0 h_c + nadh_c
ALDD2x = Reaction('ALDD2x')
ALDD2x.name = 'Aldehyde dehydrogenase'
ALDD2x.subsystem = 'Glycolysis'
ALDD2x.lower_bound = -1000
ALDD2x.upper_bound = 1000
ALDD2x.gene_reaction_rule = 'BSU19310' #KEGG левый верхний угол
ALDD2x.add_metabolites({ac_c: -1, nadh_c: -1, h_c:-2, acald_c: 1, h2o_c: 1, nad_c: 1})

#etoh_c + nad_c ⇌ acald_c + h_c + nadh_c
ALCD2x = Reaction('ALCD2x')
ALCD2x.name = 'Alcohol dehydrogenase'
ALCD2x.subsystem = 'Glycolysis'
ALCD2x.lower_bound = -1000
ALCD2x.upper_bound = 1000
ALCD2x.gene_reaction_rule = 'BSU26970' #KEGG левый верхний угол
ALCD2x.add_metabolites({acald_c: 1, h_c: 1, nadh_c: 1, etoh_c: -1, nad_c: -1})


#acald_c + h_c + nadh_c ⇌ etoh_c + nad_c
ALCD2ir = Reaction('ALCD2ir')
ALCD2ir.name = 'Alcohol dehydrogenase reverse rxn acetaldehyde ethanol'
ALCD2ir.subsystem = 'Glycolysis'
ALCD2ir.lower_bound = -1000
ALCD2ir.upper_bound = 1000
ALCD2ir.gene_reaction_rule = 'BSU27010' #KEGG левый верхний угол
ALCD2ir.add_metabolites({acald_c: -1, h_c: -1, nadh_c: -1, etoh_c: 1, nad_c: 1})
#************************************************************
#atp_c + hco3_c + pyr_c ⇌ adp_c + h_c + oaa_c + pi_c
PC = Reaction('PC')
PC.name = 'Pyruvate carboxylase'
PC.subsystem = 'Citrate cycle'
PC.lower_bound = -1000
PC.upper_bound = 1000
PC.gene_reaction_rule = 'BSU14860' #KEGG левый верхний угол
PC.add_metabolites({atp_c: -1, hco3_c: -1, pyr_c: -1, adp_c: 1, h_c: 1,  oaa_c:1, pi_c: 1})

#accoa_c + h2o_c + oaa_c ⇌ cit_c + coa_c + h_c
CS = Reaction('CS')
CS.name = 'Citrate synthase'
CS.subsystem = 'Citrate cycle'
CS.lower_bound = -1000
CS.upper_bound = 1000
CS.gene_reaction_rule = 'BSU09440' #KEGG левый верхний угол
CS.add_metabolites({accoa_c: -1, h2o_c: -1, oaa_c: -1, cit_c: 1, coa_c: 1, h_c: 1})

#mal__L_c + nad_c ⇌ h_c + nadh_c + oaa_c
MDH = Reaction('MDH')
MDH.name = 'Malate dehydrogenase'
MDH.subsystem = 'Citrate cycle'
MDH.lower_bound = -1000
MDH.upper_bound = 1000
MDH.gene_reaction_rule = 'BSU29120' #KEGG левый верхний угол
MDH.add_metabolites({oaa_c: -1, nadh_c: -1, h_c: -1, mal__L_c: 1, nad_c: 1})

#cit_c ⇌ icit_c
ACONT = Reaction('ACONT')
ACONT.name = 'Aconitate hydratase'
ACONT.subsystem = 'Citrate cycle'
ACONT.lower_bound = -1000
ACONT.upper_bound = 1000
ACONT.gene_reaction_rule = 'BSU18000' #KEGG левый верхний угол
ACONT.add_metabolites({cit_c: -1, icit_c: 1})

#icit_c + nadp_c ⇌ akg_c + co2_c + nadph_c
ICDHyr = Reaction('ICDHyr')
ICDHyr.name = 'Isocitrate dehydrogenase (NADP)'
ICDHyr.subsystem = 'Citrate cycle'
ICDHyr.lower_bound = -1000
ICDHyr.upper_bound = 1000
ICDHyr.gene_reaction_rule = 'BSU29130' #KEGG левый верхний угол
ICDHyr.add_metabolites({icit_c: -1, nadp_c: -1,akg_c: 1, co2_c: 1, nadph_c: 1})

#akg_c + h_c + lpam_c ⇌ co2_c + sdhlam_c
AKGDa = Reaction('AKGDa')
AKGDa.name = 'Oxoglutarate dehydrogenase (lipoamide)'
AKGDa.subsystem = 'Citrate cycle'
AKGDa.lower_bound = -1000
AKGDa.upper_bound = 1000
AKGDa.gene_reaction_rule = 'BSU19370' #KEGG левый верхний угол
AKGDa.add_metabolites({akg_c: -1, h_c: -1, lpam_c: -1, co2_c: 1, sdhlam_c: 1})


#dhlam_c + nad_c ⇌ h_c + lpam_c + nadh_c
PDHcr = Reaction('PDHcr')
PDHcr.name = 'Pyruvate dehydrogenase (dihydrolipoamide dehydrogenase) reversible'
PDHcr.subsystem = 'Citrate cycle'
PDHcr.lower_bound = -1000
PDHcr.upper_bound = 1000
PDHcr.gene_reaction_rule = 'BSU08090' #KEGG левый верхний угол
PDHcr.add_metabolites({h_c: -1, lpam_c: -1, nadh_c: -1, dhlam_c: 1, nad_c: 1})


#coa_c + sdhlam_c ⇌ succoa_c + dhlam_c
AKGDb = Reaction('AKGDb')
AKGDb.name = 'Oxoglutarate dehydrogenase (dihydrolipoamide S-succinyltransferase)'
AKGDb.subsystem = 'Citrate cycle'
AKGDb.lower_bound = -1000
AKGDb.upper_bound = 1000
AKGDb.gene_reaction_rule = ' BSU19360' #KEGG левый верхний угол
AKGDb.add_metabolites({coa_c: -1, sdhlam_c: -1, succoa_c: 1, dhlam_c: 1})

#atp_c + coa_c + succ_c ⇌ adp_c + pi_c + succoa_c
SUCOAS = Reaction('SUCOAS')
SUCOAS.name = 'Succinyl-CoA synthetase (ADP-forming)'
SUCOAS.subsystem = 'Citrate cycle'
SUCOAS.lower_bound = -1000
SUCOAS.upper_bound = 1000
SUCOAS.gene_reaction_rule = 'BSU16090' #KEGG левый верхний угол
SUCOAS.add_metabolites({adp_c: -1, pi_c: -1, succoa_c: -1, succ_c: 1, coa_c: 1, atp_c: 1})

#fad_c + succ_c ⇌ fadh2_c + fum_c
SUCD1 = Reaction('SUCD1')
SUCD1.name = 'Succinate dehydrogenase'
SUCD1.subsystem = 'Citrate cycle'
SUCD1.lower_bound = -1000
SUCD1.upper_bound = 1000
SUCD1.gene_reaction_rule = 'BSU28430' #KEGG левый верхний угол
SUCD1.add_metabolites({succ_c: -1, fad_c: -1, fum_c: 1, fadh2_c: 1})

#fum_c + h2o_c ⇌ mal__L_c
FUM = Reaction('FUM')
FUM.name = 'Fumarase'
FUM.subsystem = 'Citrate cycle'
FUM.lower_bound = -1000
FUM.upper_bound = 1000
FUM.gene_reaction_rule = 'BSU33040' #KEGG левый верхний угол
FUM.add_metabolites({fum_c: -1, h2o_c: -1, mal__L_c: 1})

#etoh_c + h_e ⇌ h_c + etoh_e
etoh_transport = Reaction('ETOHt3')
etoh_transport.name = 'Ethanol transport out via proton antiport'
etoh_transport.subsystem = 'Ethanol transport'
etoh_transport.lower_bound = -1000
etoh_transport.upper_bound = 0
etoh_transport.add_metabolites({etoh_c:-1, h_e:-1, etoh_e:1,  h_c:1})

# %%
# TO DO add reactions
testing_model.add_reactions([etoh_transport])
testing_model.add_reactions([hex1])
testing_model.add_reactions([glc_transport])
testing_model.add_reactions([PGI])
testing_model.add_reactions([CDS])
testing_model.add_reactions([FBA])
testing_model.add_reactions([TPI])
testing_model.add_reactions([GAPD])
testing_model.add_reactions([GAPDi_nadp])
testing_model.add_reactions([PGK])
testing_model.add_reactions([PGM])
testing_model.add_reactions([ENO])
testing_model.add_reactions([PYK])
testing_model.add_reactions([PPCK])
testing_model.add_reactions([PPS])
testing_model.add_reactions([ACS])
testing_model.add_reactions([ALDD2x])
testing_model.add_reactions([ALCD2x])
testing_model.add_reactions([ALCD2ir])
testing_model.add_reactions([FUM])
testing_model.add_reactions([SUCD1])
testing_model.add_reactions([SUCOAS])
testing_model.add_reactions([AKGDb])
testing_model.add_reactions([PDHcr])
testing_model.add_reactions([AKGDa])
testing_model.add_reactions([ICDHyr])
testing_model.add_reactions([ACONT])
testing_model.add_reactions([MDH])
testing_model.add_reactions([CS])
testing_model.add_reactions([PC])

# %%
testing_model.reactions.ALCD2ir
# Out:
# <Reaction ALCD2ir at 0x7fbb02f7f220>

# %%
# TO DO Exchange, sink and demand reactions
testing_model.add_boundary(testing_model.metabolites.get_by_id("glc_D_e"), type="exchange", lb = -10, ub = 1000)
testing_model.add_boundary(testing_model.metabolites.get_by_id('atp_c'), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id('adp_c'), type="demand")
testing_model.add_boundary(testing_model.metabolites.get_by_id("pi_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("h2o_c"), type="demand")
testing_model.add_boundary(testing_model.metabolites.get_by_id("co2_c"), type="demand")
testing_model.add_boundary(testing_model.metabolites.get_by_id("nadh_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("nadph_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("nad_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("nadp_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("ppi_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("amp_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("h_c"), type="demand")
testing_model.add_boundary(testing_model.metabolites.get_by_id("etoh_e"), type="exchange")
testing_model.add_boundary(testing_model.metabolites.get_by_id("pyr_c"), type="demand")
testing_model.add_boundary(testing_model.metabolites.get_by_id("hco3_c"), type="demand")
testing_model.add_boundary(testing_model.metabolites.get_by_id("fadh2_c"), type="sink")
testing_model.add_boundary(testing_model.metabolites.get_by_id("fad_c"), type="sink");

# %%
testing_model.objective = "DM_pyr_c"
fba = testing_model.optimize()
fba.fluxes
#testing_model.optimize()
#ALCD2x & ALCD2ir
# Out:
# ETOHt3         0.0
# HEX1          10.0
# GLCt1         10.0
# PGI           10.0
# CDS           10.0
# FBA           10.0
# TPI          -10.0
# GAPD         -20.0
# GAPDi_nadp     0.0
# PGK          -20.0
# PGM           20.0
# ENO           20.0
# PYK            0.0
# PPCK           0.0
# PPS          -20.0
# ACS            0.0
# ALDD2x         0.0
# ALCD2x         0.0
# ALCD2ir        0.0
# FUM            0.0
# SUCD1          0.0
# SUCOAS         0.0
# AKGDb          0.0
# PDHcr          0.0
# AKGDa          0.0
# ICDHyr         0.0
# ACONT          0.0
# MDH            0.0
# CS             0.0
# PC             0.0
# EX_glc_D_e   -10.0
# SK_atp_c      20.0
# DM_adp_c       0.0
# SK_pi_c      -40.0
# DM_h2o_c      40.0
# DM_co2_c       0.0
# SK_nadh_c     20.0
# SK_nadph_c     0.0
# SK_nad_c     -20.0
# SK_nadp_c      0.0
# SK_ppi_c       0.0
# SK_amp_c     -20.0
# DM_h_c         0.0
# EX_etoh_e      0.0
# DM_pyr_c      20.0
# DM_hco3_c      0.0
# SK_fadh2_c     0.0
# ...

# %%
testing_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_etoh_e = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
from cobra.flux_analysis import gapfill
solution = gapfill(testing_model, 
                   universal=None, 
                   demand_reactions=True, 
                   exchange_reactions=True 
                   )

for reaction in solution[0]:
    print(reaction.id)
# Out:
# DM_fdp_c

# %%
from cobra.flux_analysis import flux_variability_analysis
flux_variability_analysis(testing_model, testing_model.reactions)
# Out:
#             minimum  maximum
# ETOHt3          0.0      0.0
# HEX1           10.0     10.0
# GLCt1          10.0     10.0
# PGI            10.0     10.0
# CDS            10.0     10.0
# FBA            10.0     10.0
# TPI           -10.0    -10.0
# GAPD        -1000.0    980.0
# GAPDi_nadp   -980.0   1000.0
# PGK           -20.0    -20.0
# PGM            20.0     20.0
# ENO            20.0     20.0
# PYK             0.0      0.0
# PPCK            0.0      0.0
# PPS           -20.0    -20.0
# ACS             0.0      0.0
# ALDD2x          0.0      0.0
# ALCD2x      -1000.0   1000.0
# ALCD2ir     -1000.0   1000.0
# FUM             0.0      0.0
# SUCD1           0.0      0.0
# SUCOAS          0.0      0.0
# AKGDb           0.0      0.0
# PDHcr           0.0      0.0
# AKGDa           0.0      0.0
# ICDHyr          0.0      0.0
# ACONT           0.0      0.0
# MDH             0.0      0.0
# CS              0.0      0.0
# PC              0.0      0.0
# EX_glc_D_e    -10.0    -10.0
# ...

# %%
from mewpy.optimization.evaluation import BPCY
from mewpy.problems import ROUProblem
from mewpy.optimization import EA

opt = BPCY('EX_pyr_c','EX_etoh_e',  method='lMOMA')
problem = ROUProblem(testing_model, 
                     fevaluation=[opt], 
                     candidate_max_size=2)
ea = EA(problem, max_generations= 5, visualizer=True, maximize=False)
final_pop = ea.run()
# Out:
# Building modification target list.
# Running GA
# Evaluations: 100	Fitness: 0.0
# Evaluations: 200	Fitness: 0.0
# Evaluations: 300	Fitness: 0.0
# Evaluations: 400	Fitness: 0.0
# Evaluations: 500	Fitness: 0.0

# %%
import pandas as pd

ea.dataframe()
# Out:
#   Modification  Size  BPCY
# 0           {}     0   0.0

# %%
# Out:
# <h3>Objective</h3><p>1.0 ALCD2x = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#Сохранение модели или загрузка ее в различных форматах
#SBML формат
#cobra.io.read_sbml_model(join(data_dir, "name_of_the_model"))
cobra.io.write_sbml_model(testing_model, "central_metabolism_Antonova.xml")
#JSON формат
#cobra.io.load_json_model(join(data_dir, "name_of_the_model"))
cobra.io.save_json_model(testing_model, "central_metabolism_Antonova.json")

# %%
from escher import Builder
builder = Builder(
    model = cobra.io.load_json_model('central_metabolism_Antonova.json')
)
solution = builder.model.optimize()
builder.reaction_data = solution.fluxes
builder
# Out:
# Builder(reaction_data={'ETOHt3': 0.0, 'HEX1': 0.0, 'GLCt1': 0.0, 'PGI': 0.0, 'CDS': 0.0, 'FBA': 0.0, 'TPI': 0.…
